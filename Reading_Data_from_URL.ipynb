# %%
import pandas as pd

mr_robot = pd.read_html('https://en.wikipedia.org/wiki/List_of_Mr._Robot_episodes')

# %%
len(mr_robot)
# Out:
# 12

# %%
mr_robot[0]
# Out:
#   Season Episodes             Originally aired
#   Season Episodes Episodes.1       First aired          Last aired
# 0      1       10         10     June 24, 2015   September 2, 2015
# 1      2       12         12     July 13, 2016  September 21, 2016
# 2      3       10         10  October 11, 2017   December 13, 2017
# 3      4       13         13   October 6, 2019   December 22, 2019

# %%
mr_robot[1]
# Out:
#                                            No.overall  \
# 0                                                   1
# 1   Socially inept Elliot Alderson works at cyber ...
# 2                                                   2
# 3   Elliot declines a job offer from Tyrell Wellic...
# 4                                                   3
# 5   Tyrell is enraged that Scott Knowles was chose...
# 6                                                   4
# 7   Elliot has a new plan to destroy E Corp's tape...
# 8                                                   5
# 9   With the help of fsociety, Elliot infiltrates ...
# 10                                                  6
# 11  Shayla is kidnapped by Vera's brother in order...
# 12                                                  7
# 13  Flashback: Shayla moves in next door and gives...
# 14                                                  8
# 15  Darlene steals a gun, and has a conversation w...
# ...

# %%
mr_robot[10]
# Out:
#     No.                                Title           Air date  \
# 0     1                   "401 Unauthorized"    October 6, 2019
# 1     2               "402 Payment Required"   October 13, 2019
# 2     3                      "403 Forbidden"   October 20, 2019
# 3     4                      "404 Not Found"   October 27, 2019
# 4     5             "405 Method Not Allowed"   November 3, 2019
# 5     6                 "406 Not Acceptable"  November 10, 2019
# 6     7  "407 Proxy Authentication Required"  November 17, 2019
# 7     8                "408 Request Timeout"  November 24, 2019
# 8     9                       "409 Conflict"   December 1, 2019
# 9    10                           "410 Gone"   December 8, 2019
# 10   11                               "eXit"  December 15, 2019
# 11   12                             "whoami"  December 22, 2019
# 12   13                      "Hello, Elliot"  December 22, 2019
#
# ...
